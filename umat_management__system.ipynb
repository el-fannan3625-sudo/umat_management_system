# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
class Student(Person):
    def __init__(self, name,age, student_id):
        super().__init__(name, age)
        self.student_id = student_id
    def display_info(self):
        super().display_info()
        print(f"Student ID: {self.student_id}")
    def enroll_course(self, course):
        print(f"{self.name} has enrolled a {course}.")
class Lecturer(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id
    def teach_course(self, course):
        print(f"{self.name} is teaching {course}.")
student1 = Student("Annan Frank", 21,"FOE.41.006.039.25")
lecturer1 = Lecturer("Dr.Matthew", 45,"EM123")
print("------Student Information------")
student1.display_info()
student1.enroll_course("Object-Oriented Programming")
print("\n------Lecturer Information------")
lecturer1.display_info()
lecturer1.teach_course("Python Programming")
